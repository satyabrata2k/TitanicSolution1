# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing

# %matplotlib inline

# %%
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## EDA
#
# 1. Is Data Categorical?
# 2. If Not, Check Min, Max, Avg. Value.
# 3. If Categorical, what are the categories?
# 4. Are there missing values?
# 5. Find something about the distribution of variables.

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train_data.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
train_data.Sex.value_counts().plot(kind='bar')

# %%
train_data.Sex.value_counts(normalize=True).plot(kind='bar')

# %%
train_data[train_data.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
train_data.hist(figsize=(15, 20), bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000014A10518>,
# ...
#       dtype=object)

# %%
train_data.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#How many man survived
train_data[(train_data.Survived == 1) & (train_data.Sex == "male")]
# Out:
#      PassengerId  Survived  Pclass  \
# 17            18         1       2
# 21            22         1       2
# 23            24         1       1
# 36            37         1       3
# 55            56         1       1
# 65            66         1       3
# 74            75         1       3
# 78            79         1       2
# 81            82         1       3
# 97            98         1       1
# 107          108         1       3
# 125          126         1       3
# 127          128         1       3
# 146          147         1       3
# 165          166         1       3
# 183          184         1       2
# 187          188         1       1
# 193          194         1       2
# 204          205         1       3
# 207          208         1       3
# 209          210         1       1
# 220          221         1       3
# 224          225         1       1
# 226          227         1       2
# 248          249         1       1
# ...

# %%
# details of women survivor
train_data[(train_data.Survived == 1) & (train_data.Sex == "female")]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 19            20         1       3
# 22            23         1       3
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 56            57         1       2
# 58            59         1       2
# 61            62         1       1
# 66            67         1       2
# 68            69         1       3
# ...

# %%
sns.heatmap(train_data.corr())

# %%
train_data.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
train_data.shape
# Out:
# (891, 12)

# %%
len(train_data)
# Out:
# 891

# %%
train_data.groupby("Survived").Sex.value_counts()
# Out:
# Survived  Sex
# 0         male      468
#           female     81
# 1         female    233
#           male      109
# Name: Sex, dtype: int64

# %%
train_data.groupby("Survived").Sex.value_counts(normalize=True).plot(kind="bar")

# %% [markdown]
# # Handle Missing Value

# %%
train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
train_data.shape
# Out:
# (891, 12)

# %%
train_data.Embarked.describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
train_data[train_data.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
train_data.loc[train_data.Embarked.isnull(), "Embarked"] = "S"

# %%
train_data[train_data.Embarked.isnull()]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %%
#Avg. male age
train_data[train_data.Sex == "male"].Age.mean()
# Out:
# 30.72664459161148

# %%
train_data[train_data.Sex == "female"].Age.mean()
# Out:
# 27.915708812260537

# %%
train_data.loc[(train_data.Age.isnull()) & (train_data.Sex == "male"), "Age"] = train_data[train_data.Sex == "male"].Age.mean()
test_data.loc[(test_data.Age.isnull()) & (test_data.Sex == "male"), "Age"] = test_data[test_data.Sex == "male"].Age.mean()

# %%
train_data.Age.describe()
# Out:
# count    838.000000
# mean      29.851162
# std       13.412319
# min        0.420000
# 25%       22.000000
# 50%       30.726645
# 75%       36.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
train_data.loc[(train_data.Age.isnull()) & (train_data.Sex == "female"), "Age"] = train_data[train_data.Sex == "female"].Age.mean()
test_data.loc[(test_data.Age.isnull()) & (test_data.Sex == "female"), "Age"] = test_data[test_data.Sex == "female"].Age.mean()

# %%
train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         891 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Embarked    891 non-null object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 69.7+ KB

# %% [markdown]
# # Transform String Values

# %%
train_data.Sex = train_data.Sex.astype('category')

# %%
genders = {"male": 0, "female": 1}
train_data.Sex = train_data.Sex.map(genders)
test_data.Sex = test_data.Sex.map(genders)

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %% [markdown]
# # Use Scikit Learn for prediction

# %%
X_test.isnull().sum()
# Out:
# Pclass    0
# Sex       0
# Age       0
# SibSp     0
# Parch     0
# Fare      1
# dtype: int64

# %%
features = ['Pclass','Sex','Age','SibSp','Parch']

X_train = train_data.loc[:,features]
y_train = train_data.Survived

X_test = test_data.loc[:,features]

# %%
random_forest = RandomForestClassifier()
random_forest.fit(X_train, y_train)

Y_prediction = random_forest.predict(X_test)

# %% [markdown]
# # Create CSV for submission

# %%
pd.DataFrame({"PassengerId": test_data.PassengerId, "Survived": Y_prediction}).set_index("PassengerId").to_csv("Submission.csv")
